# %%
import datetime
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision as tv
import torchvision.datasets as datasets
from torchvision.utils import make_grid
from art.attacks.evasion import BasicIterativeMethod, FastGradientMethod
from art.estimators.classification import PyTorchClassifier
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset

from region_based_classifier import RegionBasedClassifier
from util import dataset2tensor, get_correct_examples

# %%
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device: {}'.format(device))

n_threads = os.cpu_count()
print('CPU threads: {}'.format(n_threads))
# Out:
# Device: cuda
# CPU threads: 24

# %%
PATH_DATA = 'data'
PATH_RESULTS = os.path.join('results', 'mnist_base_model.pt')
BATCH_SIZE = 128
EPOCHS = 20
N_ADV = 2000

# %%
# Fetch dataset
transforms = tv.transforms.Compose([tv.transforms.ToTensor()])
dataset_train = datasets.MNIST(PATH_DATA, train=True, download=True, transform=transforms)
dataset_test = datasets.MNIST(PATH_DATA, train=False, download=True, transform=transforms)

# From PyTorch dataset to Numpy array
tensor_X_train, tensor_y_train = dataset2tensor(dataset_train)
X_train = tensor_X_train.cpu().detach().numpy()
y_train = tensor_y_train.cpu().detach().numpy()
tensor_X_test, tensor_y_test = dataset2tensor(dataset_test)
X_test = tensor_X_test.cpu().detach().numpy()
y_test = tensor_y_test.cpu().detach().numpy()

# Split model training set into training set and validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=5000)
dataset_train = TensorDataset(
    torch.tensor(X_train, dtype=torch.float32),
    torch.tensor(y_train, dtype=torch.int64))

dataloader_train = DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True)
dataloader_test = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=True)

# %%
# Check sizes
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (55000, 1, 28, 28) (5000, 1, 28, 28) (10000, 1, 28, 28)

# %% [markdown]
# ## Train point-based classifier

# %%
class BaseModel(nn.Module):
    def __init__(self):
        super(BaseModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.flatten = nn.Flatten(1)
        self.fc1 = nn.Linear(9216, 200)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(200, 10)
        self.softmax = nn.Softmax(dim=1)

    def before_softmax(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.flatten(x)
        x = self.relu3(self.fc1(x))
        x = self.fc2(x)
        return x

    def forward(self, x):
        x = self.before_softmax(x)
        x = self.softmax(x)
        return x

# %%
# Create Neural Network model
model = BaseModel()
model.to(device)
print('Number of layers: {}'.format(len(list(model.children()))))
# Out:
# Number of layers: 10

# %%
def train(model, loader, loss, optimizer):
    model.train()
    total_loss = 0.
    corrects = 0.
    
    for x, y in loader:
        x = x.to(device)
        y = y.to(device)
        batch_size = x.size(0)
        
        optimizer.zero_grad()
        outputs = model(x)
        l = loss(outputs, y)
        l.backward()
        optimizer.step()

        # for display
        total_loss += l.item() * batch_size
        preds = outputs.max(1, keepdim=True)[1]
        corrects += preds.eq(y.view_as(preds)).sum().item()
    
    n = len(loader.dataset)
    total_loss = total_loss / n
    accuracy = corrects / n
    return total_loss, accuracy

# %%
def validate(model, loader, loss, device=device):
    model.eval()
    total_loss = 0.
    corrects = 0.
    
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            y = y.to(device)
            batch_size = x.size(0)
            outputs = model(x)
            l = loss(outputs, y)
            total_loss += l.item() * batch_size
            preds = outputs.max(1, keepdim=True)[1]
            corrects += preds.eq(y.view_as(preds)).sum().item()
    
    n = len(loader.dataset)
    total_loss = total_loss / n
    accuracy = corrects / n
    return total_loss, accuracy

# %%
def predict(model, X, batch_size=BATCH_SIZE, device=device):
    model.eval()
    dataset = TensorDataset(X)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    tensor_pred = -torch.ones(len(X), dtype=torch.int64)
    
    start = 0
    with torch.no_grad():
        for x in loader:
            x = x[0].to(device)
            n = x.size(0)
            end = start + n
            outputs = model(x)
            tensor_pred[start:end] = outputs.max(1)[1].type(torch.int64)
            start += n

    return tensor_pred

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
loss=nn.CrossEntropyLoss()

# %%
# DO NOT RUN THIS IF YOU DON'T NEED RETRAIN!
since = time.time()
for epoch in range(EPOCHS):
    start = time.time()
    tr_loss, tr_acc = train(model, dataloader_train, loss, optimizer)
    va_loss, va_acc = validate(model, dataloader_test, loss)
    
    time_elapsed = time.time() - start
    print(('{:2d}/{:d}[{:s}] Train Loss: {:.4f} Acc: {:.4f}%, ' +
        'Test Loss: {:.4f} Acc: {:.4f}%').format(
            epoch+1, EPOCHS, str(datetime.timedelta(seconds=time_elapsed)),
            tr_loss, tr_acc*100.,
            va_loss, va_acc*100.))
    
time_elapsed = time.time() - since
print('Total run time: {:.0f}m {:.1f}s'.format(
    time_elapsed // 60,
    time_elapsed % 60))

if not os.path.exists('results'):
    os.makedirs('results')

torch.save(model.state_dict(), PATH_RESULTS)
# Out:
#  1/20[0:00:02.383527] Train Loss: 1.9250 Acc: 60.8091%, Test Loss: 1.6499 Acc: 81.6400%
#  2/20[0:00:02.295368] Train Loss: 1.6337 Acc: 83.0509%, Test Loss: 1.6182 Acc: 84.3500%
#  3/20[0:00:02.310704] Train Loss: 1.6133 Acc: 84.9491%, Test Loss: 1.6062 Acc: 85.6200%
#  4/20[0:00:02.283891] Train Loss: 1.6021 Acc: 85.9873%, Test Loss: 1.5972 Acc: 86.4600%
#  5/20[0:00:02.263128] Train Loss: 1.5956 Acc: 86.5909%, Test Loss: 1.5936 Acc: 86.7600%
#  6/20[0:00:02.277806] Train Loss: 1.5457 Acc: 91.8000%, Test Loss: 1.5131 Acc: 95.1600%
#  7/20[0:00:02.266796] Train Loss: 1.5068 Acc: 95.6927%, Test Loss: 1.5003 Acc: 96.1800%
#  8/20[0:00:02.250070] Train Loss: 1.5019 Acc: 96.0873%, Test Loss: 1.5023 Acc: 95.9600%
#  9/20[0:00:02.269701] Train Loss: 1.4982 Acc: 96.4182%, Test Loss: 1.4981 Acc: 96.4300%
# 10/20[0:00:02.262237] Train Loss: 1.4964 Acc: 96.5945%, Test Loss: 1.4946 Acc: 96.7500%
# 11/20[0:00:02.277797] Train Loss: 1.4943 Acc: 96.8218%, Test Loss: 1.4955 Acc: 96.5700%
# 12/20[0:00:02.255239] Train Loss: 1.4925 Acc: 96.9400%, Test Loss: 1.4915 Acc: 97.0700%
# 13/20[0:00:02.257716] Train Loss: 1.4894 Acc: 97.2473%, Test Loss: 1.4915 Acc: 97.0100%
# 14/20[0:00:02.287450] Train Loss: 1.4889 Acc: 97.2782%, Test Loss: 1.4913 Acc: 97.0600%
# 15/20[0:00:02.260905] Train Loss: 1.4876 Acc: 97.4327%, Test Loss: 1.4874 Acc: 97.4600%
# 16/20[0:00:02.268877] Train Loss: 1.4859 Acc: 97.5891%, Test Loss: 1.4888 Acc: 97.2700%
# 17/20[0:00:02.283205] Train Loss: 1.4853 Acc: 97.6364%, Test Loss: 1.4868 Acc: 97.4900%
# 18/20[0:00:02.281482] Train Loss: 1.4837 Acc: 97.8309%, Test Loss: 1.4875 Acc: 97.4200%
# 19/20[0:00:02.294682] Train Loss: 1.4831 Acc: 97.8564%, Test Loss: 1.4885 Acc: 97.3000%
# 20/20[0:00:02.267167] Train Loss: 1.4814 Acc: 98.0273%, Test Loss: 1.4841 Acc: 97.7300%
# Total run time: 0m 45.6s

# %%
# Load model from saved file
model.load_state_dict(torch.load(PATH_RESULTS))

_, acc_test = validate(model, dataloader_test, loss)
print('Test set accuracy: {:.4f}'.format(acc_test*100))
# Out:
# Test set accuracy: 97.7300

# %% [markdown]
# ## Remove missclassified samples

# %%
print('Training set: {}'.format(len(dataset_train)))
tensor_train_X, tensor_train_y = get_correct_examples(model, dataset_train, device=device, return_tensor=True)
dataset_train_perfect = TensorDataset(tensor_train_X, tensor_train_y)
dataloader_train_perfect = DataLoader(dataset_train_perfect, batch_size=512, shuffle=True)
_, acc = validate(model, dataloader_train_perfect, loss)
print('Accuracy on {} filtered training examples: {:.4f}%'.format(len(dataloader_train_perfect.dataset), acc*100))

print('Test set: {}'.format(len(dataset_test)))
tensor_test_X, tensor_test_y = get_correct_examples(model, dataset_test, device=device, return_tensor=True)
dataset_test_perfect = TensorDataset(tensor_test_X, tensor_test_y)
dataloader_test_perfect = DataLoader(dataset_test_perfect, batch_size=512, shuffle=True)
_, acc = validate(model, dataloader_test_perfect, loss)
print('Accuracy on {} filtered test examples: {:.4f}%'.format(len(dataloader_test_perfect.dataset), acc*100))
# Out:
# Training set: 55000
# Accuracy on 54100 filtered training examples: 100.0000%
# Test set: 10000
# Accuracy on 9773 filtered test examples: 100.0000%

# %% [markdown]
# ## Create adversarial examples

# %%
classifier = PyTorchClassifier(
    model=model, 
    loss=loss, 
    input_shape=(1, 28, 28), 
    optimizer=optimizer,
    nb_classes=10,
    clip_values=(0.0, 1.0),
    device_type=device
)

attack = FastGradientMethod(estimator=classifier, eps=0.2)
# attack = BasicIterativeMethod(estimator=classifier, eps=0.2)

# %%
# Prepare dataset for adversarial examples
n = len(dataset_test_perfect)
indices = torch.randperm(n)[:N_ADV]

pt_subset_X = tensor_test_X[indices]  # PyTorch Tensor
pt_subset_y = tensor_test_y[indices]

subset_X = pt_subset_X.cpu().detach().numpy()
subset_y = pt_subset_y.cpu().detach().numpy()

# %%
# Create adversarial examples
subset_pred = np.argmax(classifier.predict(subset_X), axis=1)
accuracy = np.sum(subset_pred == subset_y) / float(len(subset_pred))
print("Model accuracy on clean examples: {:.4f}%".format(accuracy * 100))

# Generate adversarial examples
subset_adv = attack.generate(x=subset_X)
subset_pred = np.argmax(classifier.predict(subset_adv), axis=1)

accuracy = np.sum(subset_pred == subset_y) / float(len(subset_pred))
print("Model accuracy on adversarial examples: {:.4f}%".format(accuracy * 100))
# Out:
# Model accuracy on clean examples: 100.0000%
# Model accuracy on adversarial examples: 42.2000%

# %% [markdown]
# ## Feature Squeezing

# %%
from feature_squeezing import GaussianSqueezer, MedianSqueezer, DepthSqueezer, FeatureSqueezingTorch

# %%
squeezers = []
squeezers.append(GaussianSqueezer(x_min=0.0, x_max=1.0, noise_strength=0.025, std=1.0))
squeezers.append(MedianSqueezer(x_min=0.0, x_max=1.0, kernel_size=3))
squeezers.append(DepthSqueezer(x_min=0.0, x_max=1.0, bit_depth=8))
std = 4.1936 / 20.0
print('std=', std)
squeezers.append(GaussianSqueezer(x_min=0.0, x_max=1.0, noise_strength=1, std=std))
# Out:
# std= 0.20968

# %%
fs = FeatureSqueezingTorch(
    classifier=model,
    lr=0.001,
    momentum=0.9,
    loss=loss,
    batch_size=128,
    x_min=0.0,
    x_max=1.0,
    squeezers=squeezers,
    n_class=10,
    device=device)

# %%
fs.fit(X_train, y_train, epochs=EPOCHS, verbose=1)
# Out:
#  1/20 [0:00:01.805314] Squeezer: gaussian Train loss: 1.4767 acc: 98.5364%
#  2/20 [0:00:01.783487] Squeezer: gaussian Train loss: 1.4754 acc: 98.6400%
#  3/20 [0:00:01.786884] Squeezer: gaussian Train loss: 1.4748 acc: 98.7073%
#  4/20 [0:00:01.792756] Squeezer: gaussian Train loss: 1.4744 acc: 98.7545%
#  5/20 [0:00:01.783671] Squeezer: gaussian Train loss: 1.4741 acc: 98.7873%
#  6/20 [0:00:01.799864] Squeezer: gaussian Train loss: 1.4739 acc: 98.8236%
#  7/20 [0:00:01.783014] Squeezer: gaussian Train loss: 1.4736 acc: 98.8582%
#  8/20 [0:00:01.779295] Squeezer: gaussian Train loss: 1.4735 acc: 98.8636%
#  9/20 [0:00:01.783380] Squeezer: gaussian Train loss: 1.4733 acc: 98.8818%
# 10/20 [0:00:01.782976] Squeezer: gaussian Train loss: 1.4732 acc: 98.8909%
# 11/20 [0:00:01.786477] Squeezer: gaussian Train loss: 1.4730 acc: 98.9164%
# 12/20 [0:00:01.801955] Squeezer: gaussian Train loss: 1.4729 acc: 98.9218%
# 13/20 [0:00:01.790231] Squeezer: gaussian Train loss: 1.4728 acc: 98.9291%
# 14/20 [0:00:01.788745] Squeezer: gaussian Train loss: 1.4726 acc: 98.9509%
# 15/20 [0:00:01.791512] Squeezer: gaussian Train loss: 1.4725 acc: 98.9509%
# 16/20 [0:00:01.770448] Squeezer: gaussian Train loss: 1.4724 acc: 98.9636%
# 17/20 [0:00:01.783189] Squeezer: gaussian Train loss: 1.4723 acc: 98.9782%
# 18/20 [0:00:01.788145] Squeezer: gaussian Train loss: 1.4722 acc: 98.9964%
# 19/20 [0:00:01.788068] Squeezer: gaussian Train loss: 1.4721 acc: 99.0000%
# 20/20 [0:00:01.787082] Squeezer: gaussian Train loss: 1.4719 acc: 99.0327%
#  1/20 [0:00:01.794317] Squeezer: median Train loss: 1.4834 acc: 97.8782%
#  2/20 [0:00:01.787284] Squeezer: median Train loss: 1.4809 acc: 98.1509%
#  3/20 [0:00:01.786602] Squeezer: median Train loss: 1.4799 acc: 98.2455%
#  4/20 [0:00:01.783969] Squeezer: median Train loss: 1.4791 acc: 98.3473%
#  5/20 [0:00:01.792789] Squeezer: median Train loss: 1.4784 acc: 98.4127%
#  6/20 [0:00:01.783318] Squeezer: median Train loss: 1.4779 acc: 98.4873%
#  7/20 [0:00:01.783525] Squeezer: median Train loss: 1.4774 acc: 98.5527%
#  8/20 [0:00:01.783630] Squeezer: median Train loss: 1.4769 acc: 98.5873%
#  9/20 [0:00:01.782809] Squeezer: median Train loss: 1.4766 acc: 98.6200%
# 10/20 [0:00:01.778745] Squeezer: median Train loss: 1.4764 acc: 98.6491%
# 11/20 [0:00:01.788145] Squeezer: median Train loss: 1.4760 acc: 98.6709%
# 12/20 [0:00:01.839050] Squeezer: median Train loss: 1.4758 acc: 98.7036%
# 13/20 [0:00:01.864140] Squeezer: median Train loss: 1.4755 acc: 98.7418%
# 14/20 [0:00:01.830135] Squeezer: median Train loss: 1.4754 acc: 98.7345%
# 15/20 [0:00:01.790327] Squeezer: median Train loss: 1.4752 acc: 98.7818%
# 16/20 [0:00:01.791892] Squeezer: median Train loss: 1.4750 acc: 98.7800%
# 17/20 [0:00:01.808429] Squeezer: median Train loss: 1.4748 acc: 98.7982%
# 18/20 [0:00:01.796750] Squeezer: median Train loss: 1.4746 acc: 98.8109%
# 19/20 [0:00:01.796175] Squeezer: median Train loss: 1.4745 acc: 98.8236%
# 20/20 [0:00:01.812699] Squeezer: median Train loss: 1.4743 acc: 98.8309%
#  1/20 [0:00:01.784732] Squeezer: depth Train loss: 1.4766 acc: 98.5091%
#  2/20 [0:00:01.789015] Squeezer: depth Train loss: 1.4754 acc: 98.6618%
#  3/20 [0:00:01.784820] Squeezer: depth Train loss: 1.4748 acc: 98.7109%
#  4/20 [0:00:01.783381] Squeezer: depth Train loss: 1.4744 acc: 98.7600%
#  5/20 [0:00:01.793109] Squeezer: depth Train loss: 1.4741 acc: 98.7909%
#  6/20 [0:00:01.801407] Squeezer: depth Train loss: 1.4738 acc: 98.8109%
#  7/20 [0:00:01.818749] Squeezer: depth Train loss: 1.4736 acc: 98.8491%
#  8/20 [0:00:01.837045] Squeezer: depth Train loss: 1.4734 acc: 98.8618%
#  9/20 [0:00:01.788800] Squeezer: depth Train loss: 1.4732 acc: 98.8873%
# 10/20 [0:00:01.791491] Squeezer: depth Train loss: 1.4731 acc: 98.9018%
# 11/20 [0:00:01.789392] Squeezer: depth Train loss: 1.4730 acc: 98.9145%
# 12/20 [0:00:01.806479] Squeezer: depth Train loss: 1.4728 acc: 98.9345%
# 13/20 [0:00:01.790053] Squeezer: depth Train loss: 1.4726 acc: 98.9473%
# 14/20 [0:00:01.794038] Squeezer: depth Train loss: 1.4725 acc: 98.9709%
# 15/20 [0:00:01.791794] Squeezer: depth Train loss: 1.4724 acc: 98.9618%
# 16/20 [0:00:01.811995] Squeezer: depth Train loss: 1.4723 acc: 98.9982%
# 17/20 [0:00:01.782881] Squeezer: depth Train loss: 1.4722 acc: 99.0000%
# 18/20 [0:00:01.787581] Squeezer: depth Train loss: 1.4720 acc: 99.0182%
# 19/20 [0:00:01.788574] Squeezer: depth Train loss: 1.4720 acc: 99.0200%
# 20/20 [0:00:01.791243] Squeezer: depth Train loss: 1.4718 acc: 99.0236%
#  1/20 [0:00:01.793951] Squeezer: gaussian Train loss: 1.4825 acc: 98.0036%
#  2/20 [0:00:01.787057] Squeezer: gaussian Train loss: 1.4797 acc: 98.2636%
#  3/20 [0:00:01.792154] Squeezer: gaussian Train loss: 1.4789 acc: 98.3655%
#  4/20 [0:00:01.791424] Squeezer: gaussian Train loss: 1.4784 acc: 98.4036%
#  5/20 [0:00:01.783256] Squeezer: gaussian Train loss: 1.4779 acc: 98.4618%
#  6/20 [0:00:01.792011] Squeezer: gaussian Train loss: 1.4775 acc: 98.5236%
#  7/20 [0:00:01.787787] Squeezer: gaussian Train loss: 1.4773 acc: 98.5236%
#  8/20 [0:00:01.790550] Squeezer: gaussian Train loss: 1.4769 acc: 98.5655%
#  9/20 [0:00:01.792995] Squeezer: gaussian Train loss: 1.4767 acc: 98.5982%
# 10/20 [0:00:01.790486] Squeezer: gaussian Train loss: 1.4765 acc: 98.6273%
# 11/20 [0:00:01.793089] Squeezer: gaussian Train loss: 1.4762 acc: 98.6764%
# 12/20 [0:00:01.790462] Squeezer: gaussian Train loss: 1.4759 acc: 98.7055%
# 13/20 [0:00:01.788547] Squeezer: gaussian Train loss: 1.4757 acc: 98.7164%
# 14/20 [0:00:01.783441] Squeezer: gaussian Train loss: 1.4755 acc: 98.7400%
# 15/20 [0:00:01.790974] Squeezer: gaussian Train loss: 1.4754 acc: 98.7491%
# 16/20 [0:00:01.792321] Squeezer: gaussian Train loss: 1.4752 acc: 98.7691%
# 17/20 [0:00:01.788742] Squeezer: gaussian Train loss: 1.4750 acc: 98.7891%
# 18/20 [0:00:01.789902] Squeezer: gaussian Train loss: 1.4749 acc: 98.7855%
# 19/20 [0:00:01.788411] Squeezer: gaussian Train loss: 1.4748 acc: 98.8073%
# 20/20 [0:00:01.787733] Squeezer: gaussian Train loss: 1.4746 acc: 98.8218%

# %% [markdown]
# ## Testing FS on clean data

# %%
predictions = fs.predict(X_test)
print(predictions[:5])

print(y_test[:5])
# Out:
# [7 2 1 0 4]
# [7 2 1 0 4]

# %%
X_test_perfect = tensor_test_X.detach().numpy()
y_test_perfect = tensor_test_y.detach().numpy()

predictions = np.argmax(classifier.predict(X_test_perfect), axis=1)
accuracy = np.sum(predictions == y_test_perfect) / float(len(y_test_perfect))
print('Accuracy on origional model: {:.4f}%'.format(accuracy*100))

accuracy = fs.score(X_test_perfect, y_test_perfect)
print('Accuracy on FS model: {:.4f}%'.format(accuracy*100))
# Out:
# Accuracy on origional model: 100.0000%
# Accuracy on FS model: 99.7237%

# %% [markdown]
# ## Testing FS on Adversarial Examples

# %%
accuracy = np.sum(subset_pred == subset_y) / float(len(subset_pred))
print('Accuracy on Adversarial Examples: {:.4f}%'.format(accuracy*100))

accuracy = fs.score(subset_adv, subset_y)
print('Accuracy on FS model: {:.4f}%'.format(accuracy*100))
# Out:
# Accuracy on Adversarial Examples: 42.2000%
# Accuracy on FS model: 43.6000%

# %%
history_losses = fs.history_losses
n = len(history_losses[0])

plt.figure(figsize=(8, 6))
xx = np.arange(1, n+1)
plt.plot(xx, history_losses[0], label='Gaussian 1 loss')
plt.plot(xx, history_losses[1], label='Median loss')
plt.plot(xx, history_losses[2], label='Bit Depth loss')
plt.plot(xx, history_losses[3], label='Gaussian 2 loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
X_transformed = torch.from_numpy(X_test[:16])
grid_image = make_grid(X_transformed).permute(1, 2, 0).detach().numpy()
plt.figure(figsize=(14, 4))
plt.imshow(grid_image)
plt.axis('off')
plt.title('raw')
plt.show()

for s in squeezers:
    X_transformed = s.transform(X_test[:16])
    X_transformed = torch.from_numpy(X_transformed)
    grid_image = make_grid(X_transformed).permute(1, 2, 0).detach().numpy()
    plt.figure(figsize=(14, 4))
    plt.imshow(grid_image)
    plt.axis('off')
    plt.title(s.name)
    plt.show()
